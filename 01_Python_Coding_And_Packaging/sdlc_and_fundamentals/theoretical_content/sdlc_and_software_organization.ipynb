# %% [markdown]
# # 🏗️ Ciclo de Vida de Desenvolvimento de Software (SDLC)
#
# O desenvolvimento de um software de qualidade não se resume a escrever código. É um processo estruturado que garante que o produto final seja funcional, estável e fácil de manter.
#
# ---
# ### 📂 As 7 Fases e Nossas Ferramentas de Qualidade
#
# Abaixo, veja como os conceitos que aprendemos se encaixam no ciclo de vida profissional:
#
# 1.  **Requisitos**: Coleta de necessidades do usuário, comerciais e técnicas.
# 2.  **Análise**: Estudo da viabilidade e criação de uma solução modelo.
# 3.  **Design**: Planejamento da arquitetura do código. Aqui decidimos a criação de **Pacotes** e **Módulos**.
# 4.  **Código e Teste**: Usamos o **Pylint** para garantir a qualidade do código e o **Unittest** para realizar os testes unitários.
# 5.  **Testes de Sistema**: Verificação da funcionalidade total, incluindo **Testes de Integração**.
# 6.  **Produção**: O aplicativo é disponibilizado para os usuários finais.
# 7.  **Manutenção**: Atualizações e correções. A **Modularização** permite atualizar partes do sistema sem comprometer o todo.
#
# ---
# ### 🧩 Por que usamos Modularização e Pacotes?
#
# - **Modularização**: Dividimos o código em arquivos individuais para facilitar a manutenção e o foco em cada lógica.
# - **Pacotes**: Organizamos esses módulos em diretórios com o arquivo `__init__.py`, permitindo que um programa central chame as funções necessárias.
# - **Eficiência**: Ter vários arquivos ajuda na escalabilidade e na manutenção.
#
# ---
# ### 🛠️ Resumo das Ferramentas no Fluxo de Trabalho
#
# - **Pylint**: Garante que a fase de **Código** seja profissional e legível.
# - **Unittest**: Essencial na fase de **Teste**, garantindo que cada função retorne o valor esperado.
# - **Modularização/Pacotes**: Estrutura fundamental para as fases de **Design**, **Produção** e **Manutenção**.
#
# ---
# *Conteúdo influenciado pelo curso "IBM DevOps and Software Engineering" do Coursera.*
